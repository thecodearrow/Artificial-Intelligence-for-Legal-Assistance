# %%
from google.colab import files 
from collections import defaultdict,Counter
from nltk.stem.snowball import SnowballStemmer
import re
import pandas as pd
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize 
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.cluster import KMeans
import json
import io
import nltk
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
stemmer = SnowballStemmer("english")

#Input lemmatized cased docs
  
uploaded = files.upload()
df= pd.read_csv(io.BytesIO(uploaded['case_docs.csv']))
print(df['Content'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#      <input type="file" id="files-536b10ca-67c4-433f-ba12-96048481265d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-536b10ca-67c4-433f-ba12-96048481265d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving case_docs.csv to case_docs (1).csv
# 0       Masud Khan v State Of Uttar Pradesh\r\nSupreme...
# 1       Indian Oil Corporation v NEPC India Limited an...
# 2       Gurpal Singh v State of Punjab and Others\r\nS...
# 3       Budh Singh and Others v State of Uttar Pradesh...
# 4       Anil Kumar v State of U.P.\r\nSupreme Court of...
#                               ...
# 2909    Sukhram v State Of Maharashtra\r\nSupreme Cour...
# 2910    Satvir v State Of Uttar Pradesh\r\nSupreme Cou...
# 2911    Dharangadhara Chemical Works Limited v State o...
# 2912    Central Bank of India v M. Sethumadhavan and o...
# 2913    Som Raj @ Soma v State Of H.P.\r\nSupreme Cour...
# Name: Content, Length: 2914, dtype: object

# %%
#Some preprocessing and improving the quality of words in query/ doc


#Text Preprocessing!
def give_me_synonyms(word):
  synonyms=set()
  for synset in wordnet.synsets(word):
    for lemma in synset.lemmas():
      syn=lemma.name()
      synonyms.add(syn)
  return list(synonyms)

def expand_query(query,limit=100000):

  query_processed=remove_stop_words_and_lemmatize(query)
  query_new=[]
  count=0
  for word_current in query_processed:
    query_new.append(word_current) #make sure the old word is there
    query_synonyms=give_me_synonyms(word_current)
    for word_new in query_synonyms:
      query_new.append(word_new)
      count+=1
      if(count>limit):
        return query_new
  
  return query_new

def remove_whitespace(text): 
    return  " ".join(text.split()) 
  

def remove_punctuation(text):
    #also whitespace
    translator = str.maketrans('', '', string.punctuation) 
    return text.translate(translator)

def remove_stop_words_and_lemmatize(sentence):
  sentence=remove_punctuation(sentence)
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(sentence) 
  word_tokens=[word.lower() for word in word_tokens]
  filtered_sentence = [w for w in word_tokens if not w in stop_words]
  filtered=[token for token in filtered_sentence if not token.isdigit()]
  lemmatizer = WordNetLemmatizer()
  lemmatized_sentence=[lemmatizer.lemmatize(w) for w in filtered_sentence]  
  return lemmatized_sentence
  


N=200
#Preprocess case docs!
DF=defaultdict(set)
doc_count=defaultdict()
doc_tokens=defaultdict()
cleaned_doc_list=[]
for i,row in df.iterrows():
    doc=row['Content']
    tokens=remove_stop_words_and_lemmatize(doc)
    doc_string=' '.join(tokens)
    #doc_string=" ".join([x for x in doc_string.split() if x.isdigit() == False])
    print(i+1,"doc processing")
    if(i==1):
      print(doc_string)
    cleaned_doc_list.append(doc_string)

documents = list(cleaned_doc_list)
df['cleaned_doc']=cleaned_doc_list
print(df)
# Out:
# 1 doc processing
# 2 doc processing
# indian oil corporation v nepc india limited others supreme court india 20 july 2006 cra 834 2002 judgment delivered r v raveendran j 1 appeal filed common order dated 2932001 passed madras high court allowing crlop nos2418 1999 1563 2000 said two petition filed respondent herein u 482 criminal procedure code code short quashing complaint filed appellant cc no299 1999 file judicial magistrate no6 coimbatore cc 286 1998 file judicial magistrate alandur chennai 2 appellant indian oil corporation short ioc entered two contract one first respondent nepc india ltd sister company skyline nepc limited skyline short agreeing supply aviation turbine fuel aviation lubricant together referred aircraft fuel according appellant respect aircraft fuel supplied said contract first respondent became due sum rs5282350190 skyline became due sum rs13127642125 2941997 3 first respondent hypothecated two fokker f27500 aircraft bearing registration vtnej 12684 vtnek 10687 appellant deed hypothecation dated 151997 secure outstanding amount cl 2 said deed provided two aircraft part accessory stood hypothecated ioc way charge security payment amount due effect date hypothecation cl 3 read schedule set instalment schedule payment amount due 4 clause 6 nepc india declared would assign sell pledge charge underlet otherwise encumber part possession custody beneficial interest respect two aircraft without previous written consent ioc also undertook act may diminish value hypothecated property without clearing entire outstanding amount cl 9 provided nepc india failed pay installment interest within stipulated timeor undertaking assurance given nepc india found false ioc shall right take possession hypothecated property sell public auction private contract appropriate sale proceeds towards outstanding due without recourse court law cl 12 confirmed nepc india handed title deed relating aircraft ioc agreed receive back paying amount due stated skyline also hypothecated aircraft vtecp separate hypothecation deed dated 1451997 stated tripartite agreement dated 651997 entered among ioc nepc india skyline setting mode payment due recovery event default 5 nepc india failed pay first two installment per schedule ioc stopped supply aircraft fuel 361997 however subsequently fresh agreement dated 2091997 revised payment schedule agreed ioc agreed recommence supply aircraft fuel cash carry basis even arrangement came end installment paid 6 apprehending nepc india may remove hypothecated aircraft vtnej coimbatore airport place outside reach ioc filed c no425 1997 madras high court seeking mandatory injunction airport authority india director general civil aviation detain said aircraft stationed coimbatore airport u 8 aircraft act 1934 enable take possession thereof 7 high court granted interim injunction 1691997 restraining nepc india removing aircraft vtnej coimbatore airport regard hypothecated aircraft vtnek kept meenambakkam chennai airport ioc filed suit o no33271998 city civil court chennai similar mandatory injunction 8 ioc filed two complaint nepc india two director respondent 2 3 herein july 1998 u 200 code criminal procedure alleging unauthorized removal engine certain part two hypothecated aircraft cc 299 1999 judicial magistrate no6 coimbatore regarding aircraft bearing vtnej ii cc 286 1998 judicial magistrate alandur chennai regarding aircraft bearing vt nek 9 relevant averment complaint cc no2991999 coimbatore court read complainant state 24498 ioc come know nepc india limited total disregard order hon high court madras clandestinely removed engine certain part aircraft vtnej aircraft slno 10684 fokker f27500 stationed coimbatore airport coimbatore complainant state besides act nepc india limited removing engine certain part aircraft vtnej aircraft sl 10684 fokker f27 500 stationed coimbatore airport coimbatore term hypothecation deed dated 0151997 2091997 amount theft criminal breach trust cheating offence punishable u 378 theft 403 dishonest misappropriatio ...
# 3 doc processing
# 4 doc processing
# 5 doc processing
# 6 doc processing
# 7 doc processing
# 8 doc processing
# 9 doc processing
# 10 doc processing
# 11 doc processing
# 12 doc processing
# 13 doc processing
# 14 doc processing
# 15 doc processing
# 16 doc processing
# 17 doc processing
# 18 doc processing
# 19 doc processing
# 20 doc processing
# 21 doc processing
# 22 doc processing
# 23 doc processing
# 24 doc processing
# 25 doc processing
# 26 doc processing
# 27 doc processing
# 28 doc processing
# 29 doc processing
# 30 doc processing
# 31 doc processing
# 32 doc processing
# 33 doc processing
# 34 doc processing
# 35 doc processing
# 36 doc processing
# 37 doc processing
# 38 doc processing
# 39 doc processing
# 40 doc processing
# 41 doc processing
# 42 doc processing
# 43 doc processing
# 44 doc processing
# 45 doc processing
# 46 doc processing
# 47 doc processing
# 48 doc processing
# 49 doc processing
# 50 doc processing
# 51 doc processing
# 52 doc processing
# 53 doc processing
# 54 doc processing
# 55 doc processing
# 56 doc processing
# 57 doc processing
# 58 doc processing
# 59 doc processing
# 60 doc processing
# 61 doc processing
# 62 doc processing
# 63 doc processing
# 64 doc processing
# 65 doc processing
# 66 doc processing
# 67 doc processing
# 68 doc processing
# 69 doc processing
# 70 doc processing
# 71 doc processing
# 72 doc processing
# 73 doc processing
# 74 doc processing
# 75 doc processing
# 76 doc processing
# 77 doc processing
# 78 doc processing
# 79 doc processing
# 80 doc processing
# 81 doc processing
# 82 doc processing
# 83 doc processing
# 84 doc processing
# 85 doc processing
# 86 doc processing
# 87 doc processing
# 88 doc processing
# 89 doc processing
# 90 doc processing
# 91 doc processing
# 92 doc processing
# 93 doc processing
# 94 doc processing
# 95 doc processing
# 96 doc processing
# 97 doc processing
# 98 doc processing
# 99 doc processing
# 100 doc processing
# 101 doc processing
# 102 doc processing
# 103 doc processing
# 104 doc processing
# 105 doc processing
# 106 doc processing
# 107 doc processing
# 108 doc processing
# 109 doc processing
# 110 doc processing
# 111 doc processing
# 112 doc processing
# 113 doc processing
# 114 doc processing
# 115 doc processing
# 116 doc processing
# 117 doc processing
# 118 doc processing
# 119 doc processing
# 120 doc processing
# 121 doc processing
# 122 doc processing
# 123 doc processing
# 124 doc processing
# 125 doc processing
# 126 doc processing
# 127 doc processing
# 128 doc processing
# 129 doc processing
# 130 doc processing
# 131 doc processing
# 132 doc processing
# 133 doc processing
# 134 doc processing
# 135 doc processing
# 136 doc processing
# 137 doc processing
# 138 doc processing
# 139 doc processing
# 140 doc processing
# 141 doc processing
# 142 doc processing
# 143 doc processing
# 144 doc processing
# 145 doc processing
# 146 doc processing
# 147 doc processing
# 148 doc processing
# 149 doc processing
# 150 doc processing
# 151 doc processing
# 152 doc processing
# 153 doc processing
# 154 doc processing
# 155 doc processing
# 156 doc processing
# 157 doc processing
# 158 doc processing
# 159 doc processing
# 160 doc processing
# 161 doc processing
# 162 doc processing
# 163 doc processing
# 164 doc processing
# 165 doc processing
# 166 doc processing
# 167 doc processing
# 168 doc processing
# 169 doc processing
# 170 doc processing
# 171 doc processing
# 172 doc processing
# 173 doc processing
# 174 doc processing
# 175 doc processing
# 176 doc processing
# 177 doc processing
# 178 doc processing
# 179 doc processing
# 180 doc processing
# 181 doc processing
# 182 doc processing
# 183 doc processing
# 184 doc processing
# 185 doc processing
# 186 doc processing
# 187 doc processing
# 188 doc processing
# 189 doc processing
# 190 doc processing
# 191 doc processing
# 192 doc processing
# 193 doc processing
# 194 doc processing
# 195 doc processing
# 196 doc processing
# 197 doc processing
# 198 doc processing
# 199 doc processing
# 200 doc processing
# 201 doc processing
# 202 doc processing
# 203 doc processing
# 204 doc processing
# 205 doc processing
# 206 doc processing
# 207 doc processing
# 208 doc processing
# 209 doc processing
# 210 doc processing
# 211 doc processing
# 212 doc processing
# 213 doc processing
# 214 doc processing
# 215 doc processing
# 216 doc processing
# 217 doc processing
# 218 doc processing
# 219 doc processing
# 220 doc processing
# 221 doc processing
# 222 doc processing
# 223 doc processing
# 224 doc processing
# 225 doc processing
# 226 doc processing
# 227 doc processing
# 228 doc processing
# 229 doc processing
# 230 doc processing
# 231 doc processing
# 232 doc processing
# 233 doc processing
# 234 doc processing
# 235 doc processing
# 236 doc processing
# 237 doc processing
# 238 doc processing
# 239 doc processing
# 240 doc processing
# 241 doc processing
# 242 doc processing
# 243 doc processing
# 244 doc processing
# 245 doc processing
# 246 doc processing
# 247 doc processing
# 248 doc processing
# 249 doc processing
# 250 doc processing
# 251 doc processing
# 252 doc processing
# 253 doc processing
# 254 doc processing
# 255 doc processing
# 256 doc processing
# 257 doc processing
# 258 doc processing
# 259 doc processing
# 260 doc processing
# 261 doc processing
# 262 doc processing
# 263 doc processing
# 264 doc processing
# 265 doc processing
# 266 doc processing
# 267 doc processing
# 268 doc processing
# 269 doc processing
# 270 doc processing
# 271 doc processing
# 272 doc processing
# 273 doc processing
# 274 doc processing
# 275 doc processing
# 276 doc processing
# 277 doc processing
# 278 doc processing
# 279 doc processing
# 280 doc processing
# 281 doc processing
# 282 doc processing
# 283 doc processing
# 284 doc processing
# 285 doc processing
# 286 doc processing
# 287 doc processing
# 288 doc processing
# 289 doc processing
# 290 doc processing
# 291 doc processing
# 292 doc processing
# 293 doc processing
# 294 doc processing
# 295 doc processing
# 296 doc processing
# 297 doc processing
# 298 doc processing
# 299 doc processing
# 300 doc processing
# 301 doc processing
# 302 doc processing
# 303 doc processing
# 304 doc processing
# 305 doc processing
# 306 doc processing
# 307 doc processing
# 308 doc processing
# 309 doc processing
# 310 doc processing
# 311 doc processing
# 312 doc processing
# 313 doc processing
# 314 doc processing
# 315 doc processing
# 316 doc processing
# 317 doc processing
# 318 doc processing
# 319 doc processing
# 320 doc processing
# 321 doc processing
# 322 doc processing
# 323 doc processing
# 324 doc processing
# 325 doc processing
# 326 doc processing
# 327 doc processing
# 328 doc processing
# 329 doc processing
# 330 doc processing
# 331 doc processing
# 332 doc processing
# 333 doc processing
# 334 doc processing
# 335 doc processing
# 336 doc processing
# 337 doc processing
# 338 doc processing
# 339 doc processing
# 340 doc processing
# 341 doc processing
# 342 doc processing
# 343 doc processing
# 344 doc processing
# 345 doc processing
# 346 doc processing
# 347 doc processing
# 348 doc processing
# 349 doc processing
# 350 doc processing
# 351 doc processing
# 352 doc processing
# 353 doc processing
# 354 doc processing
# 355 doc processing
# 356 doc processing
# 357 doc processing
# 358 doc processing
# 359 doc processing
# 360 doc processing
# 361 doc processing
# 362 doc processing
# 363 doc processing
# 364 doc processing
# 365 doc processing
# 366 doc processing
# 367 doc processing
# 368 doc processing
# 369 doc processing
# 370 doc processing
# 371 doc processing
# 372 doc processing
# 373 doc processing
# 374 doc processing
# 375 doc processing
# 376 doc processing
# 377 doc processing
# 378 doc processing
# 379 doc processing
# 380 doc processing
# 381 doc processing
# 382 doc processing
# 383 doc processing
# 384 doc processing
# 385 doc processing
# 386 doc processing
# 387 doc processing
# 388 doc processing
# 389 doc processing
# 390 doc processing
# 391 doc processing
# 392 doc processing
# 393 doc processing
# 394 doc processing
# 395 doc processing
# 396 doc processing
# 397 doc processing
# 398 doc processing
# 399 doc processing
# 400 doc processing
# 401 doc processing
# 402 doc processing
# 403 doc processing
# 404 doc processing
# 405 doc processing
# 406 doc processing
# 407 doc processing
# 408 doc processing
# 409 doc processing
# 410 doc processing
# 411 doc processing
# 412 doc processing
# 413 doc processing
# 414 doc processing
# 415 doc processing
# 416 doc processing
# 417 doc processing
# 418 doc processing
# 419 doc processing
# 420 doc processing
# 421 doc processing
# 422 doc processing
# 423 doc processing
# 424 doc processing
# 425 doc processing
# 426 doc processing
# 427 doc processing
# 428 doc processing
# 429 doc processing
# 430 doc processing
# 431 doc processing
# 432 doc processing
# 433 doc processing
# 434 doc processing
# 435 doc processing
# 436 doc processing
# 437 doc processing
# 438 doc processing
# 439 doc processing
# 440 doc processing
# 441 doc processing
# 442 doc processing
# 443 doc processing
# 444 doc processing
# 445 doc processing
# 446 doc processing
# 447 doc processing
# 448 doc processing
# 449 doc processing
# 450 doc processing
# 451 doc processing
# 452 doc processing
# 453 doc processing
# 454 doc processing
# 455 doc processing
# 456 doc processing
# 457 doc processing
# 458 doc processing
# 459 doc processing
# 460 doc processing
# 461 doc processing
# 462 doc processing
# 463 doc processing
# 464 doc processing
# 465 doc processing
# 466 doc processing
# 467 doc processing
# 468 doc processing
# 469 doc processing
# 470 doc processing
# 471 doc processing
# 472 doc processing
# 473 doc processing
# 474 doc processing
# 475 doc processing
# 476 doc processing
# 477 doc processing
# 478 doc processing
# 479 doc processing
# 480 doc processing
# 481 doc processing
# 482 doc processing
# 483 doc processing
# 484 doc processing
# 485 doc processing
# 486 doc processing
# 487 doc processing
# 488 doc processing
# 489 doc processing
# 490 doc processing
# 491 doc processing
# 492 doc processing
# 493 doc processing
# 494 doc processing
# 495 doc processing
# 496 doc processing
# 497 doc processing
# 498 doc processing
# 499 doc processing
# 500 doc processing
# 501 doc processing
# 502 doc processing
# 503 doc processing
# 504 doc processing
# 505 doc processing
# 506 doc processing
# 507 doc processing
# 508 doc processing
# 509 doc processing
# 510 doc processing
# 511 doc processing
# 512 doc processing
# 513 doc processing
# 514 doc processing
# 515 doc processing
# 516 doc processing
# 517 doc processing
# 518 doc processing
# 519 doc processing
# 520 doc processing
# 521 doc processing
# 522 doc processing
# 523 doc processing
# 524 doc processing
# 525 doc processing
# 526 doc processing
# 527 doc processing
# 528 doc processing
# 529 doc processing
# 530 doc processing
# 531 doc processing
# 532 doc processing
# 533 doc processing
# 534 doc processing
# 535 doc processing
# 536 doc processing
# 537 doc processing
# 538 doc processing
# 539 doc processing
# 540 doc processing
# 541 doc processing
# 542 doc processing
# 543 doc processing
# 544 doc processing
# 545 doc processing
# 546 doc processing
# 547 doc processing
# 548 doc processing
# 549 doc processing
# 550 doc processing
# 551 doc processing
# 552 doc processing
# 553 doc processing
# 554 doc processing
# 555 doc processing
# 556 doc processing
# 557 doc processing
# 558 doc processing
# 559 doc processing
# 560 doc processing
# 561 doc processing
# 562 doc processing
# 563 doc processing
# 564 doc processing
# 565 doc processing
# 566 doc processing
# 567 doc processing
# 568 doc processing
# 569 doc processing
# 570 doc processing
# 571 doc processing
# 572 doc processing
# 573 doc processing
# 574 doc processing
# 575 doc processing
# 576 doc processing
# 577 doc processing
# 578 doc processing
# 579 doc processing
# 580 doc processing
# 581 doc processing
# 582 doc processing
# 583 doc processing
# 584 doc processing
# 585 doc processing
# 586 doc processing
# 587 doc processing
# 588 doc processing
# 589 doc processing
# 590 doc processing
# 591 doc processing
# 592 doc processing
# 593 doc processing
# 594 doc processing
# 595 doc processing
# 596 doc processing
# 597 doc processing
# 598 doc processing
# 599 doc processing
# 600 doc processing
# 601 doc processing
# 602 doc processing
# 603 doc processing
# 604 doc processing
# 605 doc processing
# 606 doc processing
# 607 doc processing
# 608 doc processing
# 609 doc processing
# 610 doc processing
# 611 doc processing
# 612 doc processing
# 613 doc processing
# 614 doc processing
# 615 doc processing
# 616 doc processing
# 617 doc processing
# 618 doc processing
# 619 doc processing
# 620 doc processing
# 621 doc processing
# 622 doc processing
# 623 doc processing
# 624 doc processing
# 625 doc processing
# 626 doc processing
# 627 doc processing
# 628 doc processing
# 629 doc processing
# 630 doc processing
# 631 doc processing
# 632 doc processing
# 633 doc processing
# 634 doc processing
# 635 doc processing
# 636 doc processing
# 637 doc processing
# 638 doc processing
# 639 doc processing
# 640 doc processing
# 641 doc processing
# 642 doc processing
# 643 doc processing
# 644 doc processing
# 645 doc processing
# 646 doc processing
# 647 doc processing
# 648 doc processing
# 649 doc processing
# 650 doc processing
# 651 doc processing
# 652 doc processing
# 653 doc processing
# 654 doc processing
# 655 doc processing
# 656 doc processing
# 657 doc processing
# 658 doc processing
# 659 doc processing
# 660 doc processing
# 661 doc processing
# 662 doc processing
# 663 doc processing
# 664 doc processing
# 665 doc processing
# 666 doc processing
# 667 doc processing
# 668 doc processing
# 669 doc processing
# 670 doc processing
# 671 doc processing
# 672 doc processing
# 673 doc processing
# 674 doc processing
# 675 doc processing
# 676 doc processing
# 677 doc processing
# 678 doc processing
# 679 doc processing
# 680 doc processing
# 681 doc processing
# 682 doc processing
# 683 doc processing
# 684 doc processing
# 685 doc processing
# 686 doc processing
# 687 doc processing
# 688 doc processing
# 689 doc processing
# 690 doc processing
# 691 doc processing
# 692 doc processing
# 693 doc processing
# 694 doc processing
# 695 doc processing
# 696 doc processing
# 697 doc processing
# 698 doc processing
# 699 doc processing
# 700 doc processing
# 701 doc processing
# 702 doc processing
# 703 doc processing
# 704 doc processing
# 705 doc processing
# 706 doc processing
# 707 doc processing
# 708 doc processing
# 709 doc processing
# 710 doc processing
# 711 doc processing
# 712 doc processing
# 713 doc processing
# 714 doc processing
# 715 doc processing
# 716 doc processing
# 717 doc processing
# 718 doc processing
# 719 doc processing
# 720 doc processing
# 721 doc processing
# 722 doc processing
# 723 doc processing
# 724 doc processing
# 725 doc processing
# 726 doc processing
# 727 doc processing
# 728 doc processing
# 729 doc processing
# 730 doc processing
# 731 doc processing
# 732 doc processing
# 733 doc processing
# 734 doc processing
# 735 doc processing
# 736 doc processing
# 737 doc processing
# 738 doc processing
# 739 doc processing
# 740 doc processing
# 741 doc processing
# 742 doc processing
# 743 doc processing
# 744 doc processing
# 745 doc processing
# 746 doc processing
# 747 doc processing
# 748 doc processing
# 749 doc processing
# 750 doc processing
# 751 doc processing
# 752 doc processing
# 753 doc processing
# 754 doc processing
# 755 doc processing
# 756 doc processing
# 757 doc processing
# 758 doc processing
# 759 doc processing
# 760 doc processing
# 761 doc processing
# 762 doc processing
# 763 doc processing
# 764 doc processing
# 765 doc processing
# 766 doc processing
# 767 doc processing
# 768 doc processing
# 769 doc processing
# 770 doc processing
# 771 doc processing
# 772 doc processing
# 773 doc processing
# 774 doc processing
# 775 doc processing
# 776 doc processing
# 777 doc processing
# 778 doc processing
# 779 doc processing
# 780 doc processing
# 781 doc processing
# 782 doc processing
# 783 doc processing
# 784 doc processing
# 785 doc processing
# 786 doc processing
# 787 doc processing
# 788 doc processing
# 789 doc processing
# 790 doc processing
# 791 doc processing
# 792 doc processing
# 793 doc processing
# 794 doc processing
# 795 doc processing
# 796 doc processing
# 797 doc processing
# 798 doc processing
# 799 doc processing
# 800 doc processing
# 801 doc processing
# 802 doc processing
# 803 doc processing
# 804 doc processing
# 805 doc processing
# 806 doc processing
# 807 doc processing
# 808 doc processing
# 809 doc processing
# 810 doc processing
# 811 doc processing
# 812 doc processing
# 813 doc processing
# 814 doc processing
# 815 doc processing
# 816 doc processing
# 817 doc processing
# 818 doc processing
# 819 doc processing
# 820 doc processing
# 821 doc processing
# 822 doc processing
# 823 doc processing
# 824 doc processing
# 825 doc processing
# 826 doc processing
# 827 doc processing
# 828 doc processing
# 829 doc processing
# 830 doc processing
# 831 doc processing
# 832 doc processing
# 833 doc processing
# 834 doc processing
# 835 doc processing
# 836 doc processing
# 837 doc processing
# 838 doc processing
# 839 doc processing
# 840 doc processing
# 841 doc processing
# 842 doc processing
# 843 doc processing
# 844 doc processing
# 845 doc processing
# 846 doc processing
# 847 doc processing
# 848 doc processing
# 849 doc processing
# 850 doc processing
# 851 doc processing
# 852 doc processing
# 853 doc processing
# 854 doc processing
# 855 doc processing
# 856 doc processing
# 857 doc processing
# 858 doc processing
# 859 doc processing
# 860 doc processing
# 861 doc processing
# 862 doc processing
# 863 doc processing
# 864 doc processing
# 865 doc processing
# 866 doc processing
# 867 doc processing
# 868 doc processing
# 869 doc processing
# 870 doc processing
# 871 doc processing
# 872 doc processing
# 873 doc processing
# 874 doc processing
# 875 doc processing
# 876 doc processing
# 877 doc processing
# 878 doc processing
# 879 doc processing
# 880 doc processing
# 881 doc processing
# 882 doc processing
# 883 doc processing
# 884 doc processing
# 885 doc processing
# 886 doc processing
# 887 doc processing
# 888 doc processing
# 889 doc processing
# 890 doc processing
# 891 doc processing
# 892 doc processing
# 893 doc processing
# 894 doc processing
# 895 doc processing
# 896 doc processing
# 897 doc processing
# 898 doc processing
# 899 doc processing
# 900 doc processing
# 901 doc processing
# 902 doc processing
# 903 doc processing
# 904 doc processing
# 905 doc processing
# 906 doc processing
# 907 doc processing
# 908 doc processing
# 909 doc processing
# 910 doc processing
# 911 doc processing
# 912 doc processing
# 913 doc processing
# 914 doc processing
# 915 doc processing
# 916 doc processing
# 917 doc processing
# 918 doc processing
# 919 doc processing
# 920 doc processing
# 921 doc processing
# 922 doc processing
# 923 doc processing
# 924 doc processing
# 925 doc processing
# 926 doc processing
# 927 doc processing
# 928 doc processing
# 929 doc processing
# 930 doc processing
# 931 doc processing
# 932 doc processing
# 933 doc processing
# 934 doc processing
# 935 doc processing
# 936 doc processing
# 937 doc processing
# 938 doc processing
# 939 doc processing
# 940 doc processing
# 941 doc processing
# 942 doc processing
# 943 doc processing
# 944 doc processing
# 945 doc processing
# 946 doc processing
# 947 doc processing
# 948 doc processing
# 949 doc processing
# 950 doc processing
# 951 doc processing
# 952 doc processing
# 953 doc processing
# 954 doc processing
# 955 doc processing
# 956 doc processing
# 957 doc processing
# 958 doc processing
# 959 doc processing
# 960 doc processing
# 961 doc processing
# 962 doc processing
# 963 doc processing
# 964 doc processing
# 965 doc processing
# 966 doc processing
# 967 doc processing
# 968 doc processing
# 969 doc processing
# 970 doc processing
# 971 doc processing
# 972 doc processing
# 973 doc processing
# 974 doc processing
# 975 doc processing
# 976 doc processing
# 977 doc processing
# 978 doc processing
# 979 doc processing
# 980 doc processing
# 981 doc processing
# 982 doc processing
# 983 doc processing
# 984 doc processing
# 985 doc processing
# 986 doc processing
# 987 doc processing
# 988 doc processing
# 989 doc processing
# 990 doc processing
# 991 doc processing
# 992 doc processing
# 993 doc processing
# 994 doc processing
# 995 doc processing
# 996 doc processing
# 997 doc processing
# 998 doc processing
# 999 doc processing
# 1000 doc processing
# 1001 doc processing
# 1002 doc processing
# 1003 doc processing
# 1004 doc processing
# 1005 doc processing
# 1006 doc processing
# 1007 doc processing
# 1008 doc processing
# 1009 doc processing
# 1010 doc processing
# 1011 doc processing
# 1012 doc processing
# 1013 doc processing
# 1014 doc processing
# 1015 doc processing
# 1016 doc processing
# 1017 doc processing
# 1018 doc processing
# 1019 doc processing
# 1020 doc processing
# 1021 doc processing
# 1022 doc processing
# 1023 doc processing
# 1024 doc processing
# 1025 doc processing
# 1026 doc processing
# 1027 doc processing
# 1028 doc processing
# 1029 doc processing
# 1030 doc processing
# 1031 doc processing
# 1032 doc processing
# 1033 doc processing
# 1034 doc processing
# 1035 doc processing
# 1036 doc processing
# 1037 doc processing
# 1038 doc processing
# 1039 doc processing
# 1040 doc processing
# 1041 doc processing
# 1042 doc processing
# 1043 doc processing
# 1044 doc processing
# 1045 doc processing
# 1046 doc processing
# 1047 doc processing
# 1048 doc processing
# 1049 doc processing
# 1050 doc processing
# 1051 doc processing
# 1052 doc processing
# 1053 doc processing
# 1054 doc processing
# 1055 doc processing
# 1056 doc processing
# 1057 doc processing
# 1058 doc processing
# 1059 doc processing
# 1060 doc processing
# 1061 doc processing
# 1062 doc processing
# 1063 doc processing
# 1064 doc processing
# 1065 doc processing
# 1066 doc processing
# 1067 doc processing
# 1068 doc processing
# 1069 doc processing
# 1070 doc processing
# 1071 doc processing
# 1072 doc processing
# 1073 doc processing
# 1074 doc processing
# 1075 doc processing
# 1076 doc processing
# 1077 doc processing
# 1078 doc processing
# 1079 doc processing
# 1080 doc processing
# 1081 doc processing
# 1082 doc processing
# 1083 doc processing
# 1084 doc processing
# 1085 doc processing
# 1086 doc processing
# 1087 doc processing
# 1088 doc processing
# 1089 doc processing
# 1090 doc processing
# 1091 doc processing
# 1092 doc processing
# 1093 doc processing
# 1094 doc processing
# 1095 doc processing
# 1096 doc processing
# 1097 doc processing
# 1098 doc processing
# 1099 doc processing
# 1100 doc processing
# 1101 doc processing
# 1102 doc processing
# 1103 doc processing
# 1104 doc processing
# 1105 doc processing
# 1106 doc processing
# 1107 doc processing
# 1108 doc processing
# 1109 doc processing
# 1110 doc processing
# 1111 doc processing
# 1112 doc processing
# 1113 doc processing
# 1114 doc processing
# 1115 doc processing
# 1116 doc processing
# 1117 doc processing
# 1118 doc processing
# 1119 doc processing
# 1120 doc processing
# 1121 doc processing
# 1122 doc processing
# 1123 doc processing
# 1124 doc processing
# 1125 doc processing
# 1126 doc processing
# 1127 doc processing
# 1128 doc processing
# 1129 doc processing
# 1130 doc processing
# 1131 doc processing
# 1132 doc processing
# 1133 doc processing
# 1134 doc processing
# 1135 doc processing
# 1136 doc processing
# 1137 doc processing
# 1138 doc processing
# 1139 doc processing
# 1140 doc processing
# 1141 doc processing
# 1142 doc processing
# 1143 doc processing
# 1144 doc processing
# 1145 doc processing
# 1146 doc processing
# 1147 doc processing
# 1148 doc processing
# 1149 doc processing
# 1150 doc processing
# 1151 doc processing
# 1152 doc processing
# 1153 doc processing
# 1154 doc processing
# 1155 doc processing
# 1156 doc processing
# 1157 doc processing
# 1158 doc processing
# 1159 doc processing
# 1160 doc processing
# 1161 doc processing
# 1162 doc processing
# 1163 doc processing
# 1164 doc processing
# 1165 doc processing
# 1166 doc processing
# 1167 doc processing
# 1168 doc processing
# 1169 doc processing
# 1170 doc processing
# 1171 doc processing
# 1172 doc processing
# 1173 doc processing
# 1174 doc processing
# 1175 doc processing
# 1176 doc processing
# 1177 doc processing
# 1178 doc processing
# 1179 doc processing
# 1180 doc processing
# 1181 doc processing
# 1182 doc processing
# 1183 doc processing
# 1184 doc processing
# 1185 doc processing
# 1186 doc processing
# 1187 doc processing
# 1188 doc processing
# 1189 doc processing
# 1190 doc processing
# 1191 doc processing
# 1192 doc processing
# 1193 doc processing
# 1194 doc processing
# 1195 doc processing
# 1196 doc processing
# 1197 doc processing
# 1198 doc processing
# 1199 doc processing
# 1200 doc processing
# 1201 doc processing
# 1202 doc processing
# 1203 doc processing
# 1204 doc processing
# 1205 doc processing
# 1206 doc processing
# 1207 doc processing
# 1208 doc processing
# 1209 doc processing
# 1210 doc processing
# 1211 doc processing
# 1212 doc processing
# 1213 doc processing
# 1214 doc processing
# 1215 doc processing
# 1216 doc processing
# 1217 doc processing
# 1218 doc processing
# 1219 doc processing
# 1220 doc processing
# 1221 doc processing
# 1222 doc processing
# 1223 doc processing
# 1224 doc processing
# 1225 doc processing
# 1226 doc processing
# 1227 doc processing
# 1228 doc processing
# 1229 doc processing
# 1230 doc processing
# 1231 doc processing
# 1232 doc processing
# 1233 doc processing
# 1234 doc processing
# 1235 doc processing
# 1236 doc processing
# 1237 doc processing
# 1238 doc processing
# 1239 doc processing
# 1240 doc processing
# 1241 doc processing
# 1242 doc processing
# 1243 doc processing
# 1244 doc processing
# 1245 doc processing
# 1246 doc processing
# 1247 doc processing
# 1248 doc processing
# 1249 doc processing
# 1250 doc processing
# 1251 doc processing
# 1252 doc processing
# 1253 doc processing
# 1254 doc processing
# 1255 doc processing
# 1256 doc processing
# 1257 doc processing
# 1258 doc processing
# 1259 doc processing
# 1260 doc processing
# 1261 doc processing
# 1262 doc processing
# 1263 doc processing
# 1264 doc processing
# 1265 doc processing
# 1266 doc processing
# 1267 doc processing
# 1268 doc processing
# 1269 doc processing
# 1270 doc processing
# 1271 doc processing
# 1272 doc processing
# 1273 doc processing
# 1274 doc processing
# 1275 doc processing
# 1276 doc processing
# 1277 doc processing
# 1278 doc processing
# 1279 doc processing
# 1280 doc processing
# 1281 doc processing
# 1282 doc processing
# 1283 doc processing
# 1284 doc processing
# 1285 doc processing
# 1286 doc processing
# 1287 doc processing
# 1288 doc processing
# 1289 doc processing
# 1290 doc processing
# 1291 doc processing
# 1292 doc processing
# 1293 doc processing
# 1294 doc processing
# 1295 doc processing
# 1296 doc processing
# 1297 doc processing
# 1298 doc processing
# 1299 doc processing
# 1300 doc processing
# 1301 doc processing
# 1302 doc processing
# 1303 doc processing
# 1304 doc processing
# 1305 doc processing
# 1306 doc processing
# 1307 doc processing
# 1308 doc processing
# 1309 doc processing
# 1310 doc processing
# 1311 doc processing
# 1312 doc processing
# 1313 doc processing
# 1314 doc processing
# 1315 doc processing
# 1316 doc processing
# 1317 doc processing
# 1318 doc processing
# 1319 doc processing
# 1320 doc processing
# 1321 doc processing
# 1322 doc processing
# 1323 doc processing
# 1324 doc processing
# 1325 doc processing
# 1326 doc processing
# 1327 doc processing
# 1328 doc processing
# 1329 doc processing
# 1330 doc processing
# 1331 doc processing
# 1332 doc processing
# 1333 doc processing
# 1334 doc processing
# 1335 doc processing
# 1336 doc processing
# 1337 doc processing
# 1338 doc processing
# 1339 doc processing
# 1340 doc processing
# 1341 doc processing
# 1342 doc processing
# 1343 doc processing
# 1344 doc processing
# 1345 doc processing
# 1346 doc processing
# 1347 doc processing
# 1348 doc processing
# 1349 doc processing
# 1350 doc processing
# 1351 doc processing
# 1352 doc processing
# 1353 doc processing
# 1354 doc processing
# 1355 doc processing
# 1356 doc processing
# 1357 doc processing
# 1358 doc processing
# 1359 doc processing
# 1360 doc processing
# 1361 doc processing
# 1362 doc processing
# 1363 doc processing
# 1364 doc processing
# 1365 doc processing
# 1366 doc processing
# 1367 doc processing
# 1368 doc processing
# 1369 doc processing
# 1370 doc processing
# 1371 doc processing
# 1372 doc processing
# 1373 doc processing
# 1374 doc processing
# 1375 doc processing
# 1376 doc processing
# 1377 doc processing
# 1378 doc processing
# 1379 doc processing
# 1380 doc processing
# 1381 doc processing
# 1382 doc processing
# 1383 doc processing
# 1384 doc processing
# 1385 doc processing
# 1386 doc processing
# 1387 doc processing
# 1388 doc processing
# 1389 doc processing
# 1390 doc processing
# 1391 doc processing
# 1392 doc processing
# 1393 doc processing
# 1394 doc processing
# 1395 doc processing
# 1396 doc processing
# 1397 doc processing
# 1398 doc processing
# 1399 doc processing
# 1400 doc processing
# 1401 doc processing
# 1402 doc processing
# 1403 doc processing
# 1404 doc processing
# 1405 doc processing
# 1406 doc processing
# 1407 doc processing
# 1408 doc processing
# 1409 doc processing
# 1410 doc processing
# 1411 doc processing
# 1412 doc processing
# 1413 doc processing
# 1414 doc processing
# 1415 doc processing
# 1416 doc processing
# 1417 doc processing
# 1418 doc processing
# 1419 doc processing
# 1420 doc processing
# 1421 doc processing
# 1422 doc processing
# 1423 doc processing
# 1424 doc processing
# 1425 doc processing
# 1426 doc processing
# 1427 doc processing
# 1428 doc processing
# 1429 doc processing
# 1430 doc processing
# 1431 doc processing
# 1432 doc processing
# 1433 doc processing
# 1434 doc processing
# 1435 doc processing
# 1436 doc processing
# 1437 doc processing
# 1438 doc processing
# 1439 doc processing
# 1440 doc processing
# 1441 doc processing
# 1442 doc processing
# 1443 doc processing
# 1444 doc processing
# 1445 doc processing
# 1446 doc processing
# 1447 doc processing
# 1448 doc processing
# 1449 doc processing
# 1450 doc processing
# 1451 doc processing
# 1452 doc processing
# 1453 doc processing
# 1454 doc processing
# 1455 doc processing
# 1456 doc processing
# 1457 doc processing
# 1458 doc processing
# 1459 doc processing
# 1460 doc processing
# 1461 doc processing
# 1462 doc processing
# 1463 doc processing
# 1464 doc processing
# 1465 doc processing
# 1466 doc processing
# 1467 doc processing
# 1468 doc processing
# 1469 doc processing
# 1470 doc processing
# 1471 doc processing
# 1472 doc processing
# 1473 doc processing
# 1474 doc processing
# 1475 doc processing
# 1476 doc processing
# 1477 doc processing
# 1478 doc processing
# 1479 doc processing
# 1480 doc processing
# 1481 doc processing
# 1482 doc processing
# 1483 doc processing
# 1484 doc processing
# 1485 doc processing
# 1486 doc processing
# 1487 doc processing
# 1488 doc processing
# 1489 doc processing
# 1490 doc processing
# 1491 doc processing
# 1492 doc processing
# 1493 doc processing
# 1494 doc processing
# 1495 doc processing
# 1496 doc processing
# 1497 doc processing
# 1498 doc processing
# 1499 doc processing
# 1500 doc processing
# 1501 doc processing
# 1502 doc processing
# 1503 doc processing
# 1504 doc processing
# 1505 doc processing
# 1506 doc processing
# 1507 doc processing
# 1508 doc processing
# 1509 doc processing
# 1510 doc processing
# 1511 doc processing
# 1512 doc processing
# 1513 doc processing
# 1514 doc processing
# 1515 doc processing
# 1516 doc processing
# 1517 doc processing
# 1518 doc processing
# 1519 doc processing
# 1520 doc processing
# 1521 doc processing
# 1522 doc processing
# 1523 doc processing
# 1524 doc processing
# 1525 doc processing
# 1526 doc processing
# 1527 doc processing
# 1528 doc processing
# 1529 doc processing
# 1530 doc processing
# 1531 doc processing
# 1532 doc processing
# 1533 doc processing
# 1534 doc processing
# 1535 doc processing
# 1536 doc processing
# 1537 doc processing
# 1538 doc processing
# 1539 doc processing
# 1540 doc processing
# 1541 doc processing
# 1542 doc processing
# 1543 doc processing
# 1544 doc processing
# 1545 doc processing
# 1546 doc processing
# 1547 doc processing
# 1548 doc processing
# 1549 doc processing
# 1550 doc processing
# 1551 doc processing
# 1552 doc processing
# 1553 doc processing
# 1554 doc processing
# 1555 doc processing
# 1556 doc processing
# 1557 doc processing
# 1558 doc processing
# 1559 doc processing
# 1560 doc processing
# 1561 doc processing
# 1562 doc processing
# 1563 doc processing
# 1564 doc processing
# 1565 doc processing
# 1566 doc processing
# 1567 doc processing
# 1568 doc processing
# 1569 doc processing
# 1570 doc processing
# 1571 doc processing
# 1572 doc processing
# 1573 doc processing
# 1574 doc processing
# 1575 doc processing
# 1576 doc processing
# 1577 doc processing
# 1578 doc processing
# 1579 doc processing
# 1580 doc processing
# 1581 doc processing
# 1582 doc processing
# 1583 doc processing
# 1584 doc processing
# 1585 doc processing
# 1586 doc processing
# 1587 doc processing
# 1588 doc processing
# 1589 doc processing
# 1590 doc processing
# 1591 doc processing
# 1592 doc processing
# 1593 doc processing
# 1594 doc processing
# 1595 doc processing
# 1596 doc processing
# 1597 doc processing
# 1598 doc processing
# 1599 doc processing
# 1600 doc processing
# 1601 doc processing
# 1602 doc processing
# 1603 doc processing
# 1604 doc processing
# 1605 doc processing
# 1606 doc processing
# 1607 doc processing
# 1608 doc processing
# 1609 doc processing
# 1610 doc processing
# 1611 doc processing
# 1612 doc processing
# 1613 doc processing
# 1614 doc processing
# 1615 doc processing
# 1616 doc processing
# 1617 doc processing
# 1618 doc processing
# 1619 doc processing
# 1620 doc processing
# 1621 doc processing
# 1622 doc processing
# 1623 doc processing
# 1624 doc processing
# 1625 doc processing
# 1626 doc processing
# 1627 doc processing
# 1628 doc processing
# 1629 doc processing
# 1630 doc processing
# 1631 doc processing
# 1632 doc processing
# 1633 doc processing
# 1634 doc processing
# 1635 doc processing
# 1636 doc processing
# 1637 doc processing
# 1638 doc processing
# 1639 doc processing
# 1640 doc processing
# 1641 doc processing
# 1642 doc processing
# 1643 doc processing
# 1644 doc processing
# 1645 doc processing
# 1646 doc processing
# 1647 doc processing
# 1648 doc processing
# 1649 doc processing
# 1650 doc processing
# 1651 doc processing
# 1652 doc processing
# 1653 doc processing
# 1654 doc processing
# 1655 doc processing
# 1656 doc processing
# 1657 doc processing
# 1658 doc processing
# 1659 doc processing
# 1660 doc processing
# 1661 doc processing
# 1662 doc processing
# 1663 doc processing
# 1664 doc processing
# 1665 doc processing
# 1666 doc processing
# 1667 doc processing
# 1668 doc processing
# 1669 doc processing
# 1670 doc processing
# 1671 doc processing
# 1672 doc processing
# 1673 doc processing
# 1674 doc processing
# 1675 doc processing
# 1676 doc processing
# 1677 doc processing
# 1678 doc processing
# 1679 doc processing
# 1680 doc processing
# 1681 doc processing
# 1682 doc processing
# 1683 doc processing
# 1684 doc processing
# 1685 doc processing
# 1686 doc processing
# 1687 doc processing
# 1688 doc processing
# 1689 doc processing
# 1690 doc processing
# 1691 doc processing
# 1692 doc processing
# 1693 doc processing
# 1694 doc processing
# 1695 doc processing
# 1696 doc processing
# 1697 doc processing
# 1698 doc processing
# 1699 doc processing
# 1700 doc processing
# 1701 doc processing
# 1702 doc processing
# 1703 doc processing
# 1704 doc processing
# 1705 doc processing
# 1706 doc processing
# 1707 doc processing
# 1708 doc processing
# 1709 doc processing
# 1710 doc processing
# 1711 doc processing
# 1712 doc processing
# 1713 doc processing
# 1714 doc processing
# 1715 doc processing
# 1716 doc processing
# 1717 doc processing
# 1718 doc processing
# 1719 doc processing
# 1720 doc processing
# 1721 doc processing
# 1722 doc processing
# 1723 doc processing
# 1724 doc processing
# 1725 doc processing
# 1726 doc processing
# 1727 doc processing
# 1728 doc processing
# 1729 doc processing
# 1730 doc processing
# 1731 doc processing
# 1732 doc processing
# 1733 doc processing
# 1734 doc processing
# 1735 doc processing
# 1736 doc processing
# 1737 doc processing
# 1738 doc processing
# 1739 doc processing
# 1740 doc processing
# 1741 doc processing
# 1742 doc processing
# 1743 doc processing
# 1744 doc processing
# 1745 doc processing
# 1746 doc processing
# 1747 doc processing
# 1748 doc processing
# 1749 doc processing
# 1750 doc processing
# 1751 doc processing
# 1752 doc processing
# 1753 doc processing
# 1754 doc processing
# 1755 doc processing
# 1756 doc processing
# 1757 doc processing
# 1758 doc processing
# 1759 doc processing
# 1760 doc processing
# 1761 doc processing
# 1762 doc processing
# 1763 doc processing
# 1764 doc processing
# 1765 doc processing
# 1766 doc processing
# 1767 doc processing
# 1768 doc processing
# 1769 doc processing
# 1770 doc processing
# 1771 doc processing
# 1772 doc processing
# 1773 doc processing
# 1774 doc processing
# 1775 doc processing
# 1776 doc processing
# 1777 doc processing
# 1778 doc processing
# 1779 doc processing
# 1780 doc processing
# 1781 doc processing
# 1782 doc processing
# 1783 doc processing
# 1784 doc processing
# 1785 doc processing
# 1786 doc processing
# 1787 doc processing
# 1788 doc processing
# 1789 doc processing
# 1790 doc processing
# 1791 doc processing
# 1792 doc processing
# 1793 doc processing
# 1794 doc processing
# 1795 doc processing
# 1796 doc processing
# 1797 doc processing
# 1798 doc processing
# 1799 doc processing
# 1800 doc processing
# 1801 doc processing
# 1802 doc processing
# 1803 doc processing
# 1804 doc processing
# 1805 doc processing
# 1806 doc processing
# 1807 doc processing
# 1808 doc processing
# 1809 doc processing
# 1810 doc processing
# 1811 doc processing
# 1812 doc processing
# 1813 doc processing
# 1814 doc processing
# 1815 doc processing
# 1816 doc processing
# 1817 doc processing
# 1818 doc processing
# 1819 doc processing
# 1820 doc processing
# 1821 doc processing
# 1822 doc processing
# 1823 doc processing
# 1824 doc processing
# 1825 doc processing
# 1826 doc processing
# 1827 doc processing
# 1828 doc processing
# 1829 doc processing
# 1830 doc processing
# 1831 doc processing
# 1832 doc processing
# 1833 doc processing
# 1834 doc processing
# 1835 doc processing
# 1836 doc processing
# 1837 doc processing
# 1838 doc processing
# 1839 doc processing
# 1840 doc processing
# 1841 doc processing
# 1842 doc processing
# 1843 doc processing
# 1844 doc processing
# 1845 doc processing
# 1846 doc processing
# 1847 doc processing
# 1848 doc processing
# 1849 doc processing
# 1850 doc processing
# 1851 doc processing
# 1852 doc processing
# 1853 doc processing
# 1854 doc processing
# 1855 doc processing
# 1856 doc processing
# 1857 doc processing
# 1858 doc processing
# 1859 doc processing
# 1860 doc processing
# 1861 doc processing
# 1862 doc processing
# 1863 doc processing
# 1864 doc processing
# 1865 doc processing
# 1866 doc processing
# 1867 doc processing
# 1868 doc processing
# 1869 doc processing
# 1870 doc processing
# 1871 doc processing
# 1872 doc processing
# 1873 doc processing
# 1874 doc processing
# 1875 doc processing
# 1876 doc processing
# 1877 doc processing
# 1878 doc processing
# 1879 doc processing
# 1880 doc processing
# 1881 doc processing
# 1882 doc processing
# 1883 doc processing
# 1884 doc processing
# 1885 doc processing
# 1886 doc processing
# 1887 doc processing
# 1888 doc processing
# 1889 doc processing
# 1890 doc processing
# 1891 doc processing
# 1892 doc processing
# 1893 doc processing
# 1894 doc processing
# 1895 doc processing
# 1896 doc processing
# 1897 doc processing
# 1898 doc processing
# 1899 doc processing
# 1900 doc processing
# 1901 doc processing
# 1902 doc processing
# 1903 doc processing
# 1904 doc processing
# 1905 doc processing
# 1906 doc processing
# 1907 doc processing
# 1908 doc processing
# 1909 doc processing
# 1910 doc processing
# 1911 doc processing
# 1912 doc processing
# 1913 doc processing
# 1914 doc processing
# 1915 doc processing
# 1916 doc processing
# 1917 doc processing
# 1918 doc processing
# 1919 doc processing
# 1920 doc processing
# 1921 doc processing
# 1922 doc processing
# 1923 doc processing
# 1924 doc processing
# 1925 doc processing
# 1926 doc processing
# 1927 doc processing
# 1928 doc processing
# 1929 doc processing
# 1930 doc processing
# 1931 doc processing
# 1932 doc processing
# 1933 doc processing
# 1934 doc processing
# 1935 doc processing
# 1936 doc processing
# 1937 doc processing
# 1938 doc processing
# 1939 doc processing
# 1940 doc processing
# 1941 doc processing
# 1942 doc processing
# 1943 doc processing
# 1944 doc processing
# 1945 doc processing
# 1946 doc processing
# 1947 doc processing
# 1948 doc processing
# 1949 doc processing
# 1950 doc processing
# 1951 doc processing
# 1952 doc processing
# 1953 doc processing
# 1954 doc processing
# 1955 doc processing
# 1956 doc processing
# 1957 doc processing
# 1958 doc processing
# 1959 doc processing
# 1960 doc processing
# 1961 doc processing
# 1962 doc processing
# 1963 doc processing
# 1964 doc processing
# 1965 doc processing
# 1966 doc processing
# 1967 doc processing
# 1968 doc processing
# 1969 doc processing
# 1970 doc processing
# 1971 doc processing
# 1972 doc processing
# 1973 doc processing
# 1974 doc processing
# 1975 doc processing
# 1976 doc processing
# 1977 doc processing
# 1978 doc processing
# 1979 doc processing
# 1980 doc processing
# 1981 doc processing
# 1982 doc processing
# 1983 doc processing
# 1984 doc processing
# 1985 doc processing
# 1986 doc processing
# 1987 doc processing
# 1988 doc processing
# 1989 doc processing
# 1990 doc processing
# 1991 doc processing
# 1992 doc processing
# 1993 doc processing
# 1994 doc processing
# 1995 doc processing
# 1996 doc processing
# 1997 doc processing
# 1998 doc processing
# 1999 doc processing
# 2000 doc processing
# 2001 doc processing
# 2002 doc processing
# 2003 doc processing
# 2004 doc processing
# 2005 doc processing
# 2006 doc processing
# 2007 doc processing
# 2008 doc processing
# 2009 doc processing
# 2010 doc processing
# 2011 doc processing
# 2012 doc processing
# 2013 doc processing
# 2014 doc processing
# 2015 doc processing
# 2016 doc processing
# 2017 doc processing
# 2018 doc processing
# 2019 doc processing
# 2020 doc processing
# 2021 doc processing
# 2022 doc processing
# 2023 doc processing
# 2024 doc processing
# 2025 doc processing
# 2026 doc processing
# 2027 doc processing
# 2028 doc processing
# 2029 doc processing
# 2030 doc processing
# 2031 doc processing
# 2032 doc processing
# 2033 doc processing
# 2034 doc processing
# 2035 doc processing
# 2036 doc processing
# 2037 doc processing
# 2038 doc processing
# 2039 doc processing
# 2040 doc processing
# 2041 doc processing
# 2042 doc processing
# 2043 doc processing
# 2044 doc processing
# 2045 doc processing
# 2046 doc processing
# 2047 doc processing
# 2048 doc processing
# 2049 doc processing
# 2050 doc processing
# 2051 doc processing
# 2052 doc processing
# 2053 doc processing
# 2054 doc processing
# 2055 doc processing
# 2056 doc processing
# 2057 doc processing
# 2058 doc processing
# 2059 doc processing
# 2060 doc processing
# 2061 doc processing
# 2062 doc processing
# 2063 doc processing
# 2064 doc processing
# 2065 doc processing
# 2066 doc processing
# 2067 doc processing
# 2068 doc processing
# 2069 doc processing
# 2070 doc processing
# 2071 doc processing
# 2072 doc processing
# 2073 doc processing
# 2074 doc processing
# 2075 doc processing
# 2076 doc processing
# 2077 doc processing
# 2078 doc processing
# 2079 doc processing
# 2080 doc processing
# 2081 doc processing
# 2082 doc processing
# 2083 doc processing
# 2084 doc processing
# 2085 doc processing
# 2086 doc processing
# 2087 doc processing
# 2088 doc processing
# 2089 doc processing
# 2090 doc processing
# 2091 doc processing
# 2092 doc processing
# 2093 doc processing
# 2094 doc processing
# 2095 doc processing
# 2096 doc processing
# 2097 doc processing
# 2098 doc processing
# 2099 doc processing
# 2100 doc processing
# 2101 doc processing
# 2102 doc processing
# 2103 doc processing
# 2104 doc processing
# 2105 doc processing
# 2106 doc processing
# 2107 doc processing
# 2108 doc processing
# 2109 doc processing
# 2110 doc processing
# 2111 doc processing
# 2112 doc processing
# 2113 doc processing
# 2114 doc processing
# 2115 doc processing
# 2116 doc processing
# 2117 doc processing
# 2118 doc processing
# 2119 doc processing
# 2120 doc processing
# 2121 doc processing
# 2122 doc processing
# 2123 doc processing
# 2124 doc processing
# 2125 doc processing
# 2126 doc processing
# 2127 doc processing
# 2128 doc processing
# 2129 doc processing
# 2130 doc processing
# 2131 doc processing
# 2132 doc processing
# 2133 doc processing
# 2134 doc processing
# 2135 doc processing
# 2136 doc processing
# 2137 doc processing
# 2138 doc processing
# 2139 doc processing
# 2140 doc processing
# 2141 doc processing
# 2142 doc processing
# 2143 doc processing
# 2144 doc processing
# 2145 doc processing
# 2146 doc processing
# 2147 doc processing
# 2148 doc processing
# 2149 doc processing
# 2150 doc processing
# 2151 doc processing
# 2152 doc processing
# 2153 doc processing
# 2154 doc processing
# 2155 doc processing
# 2156 doc processing
# 2157 doc processing
# 2158 doc processing
# 2159 doc processing
# 2160 doc processing
# 2161 doc processing
# 2162 doc processing
# 2163 doc processing
# 2164 doc processing
# 2165 doc processing
# 2166 doc processing
# 2167 doc processing
# 2168 doc processing
# 2169 doc processing
# 2170 doc processing
# 2171 doc processing
# 2172 doc processing
# 2173 doc processing
# 2174 doc processing
# 2175 doc processing
# 2176 doc processing
# 2177 doc processing
# 2178 doc processing
# 2179 doc processing
# 2180 doc processing
# 2181 doc processing
# 2182 doc processing
# 2183 doc processing
# 2184 doc processing
# 2185 doc processing
# 2186 doc processing
# 2187 doc processing
# 2188 doc processing
# 2189 doc processing
# 2190 doc processing
# 2191 doc processing
# 2192 doc processing
# 2193 doc processing
# 2194 doc processing
# 2195 doc processing
# 2196 doc processing
# 2197 doc processing
# 2198 doc processing
# 2199 doc processing
# 2200 doc processing
# 2201 doc processing
# 2202 doc processing
# 2203 doc processing
# 2204 doc processing
# 2205 doc processing
# 2206 doc processing
# 2207 doc processing
# 2208 doc processing
# 2209 doc processing
# 2210 doc processing
# 2211 doc processing
# 2212 doc processing
# 2213 doc processing
# 2214 doc processing
# 2215 doc processing
# 2216 doc processing
# 2217 doc processing
# 2218 doc processing
# 2219 doc processing
# 2220 doc processing
# 2221 doc processing
# 2222 doc processing
# 2223 doc processing
# 2224 doc processing
# 2225 doc processing
# 2226 doc processing
# 2227 doc processing
# 2228 doc processing
# 2229 doc processing
# 2230 doc processing
# 2231 doc processing
# 2232 doc processing
# 2233 doc processing
# 2234 doc processing
# 2235 doc processing
# 2236 doc processing
# 2237 doc processing
# 2238 doc processing
# 2239 doc processing
# 2240 doc processing
# 2241 doc processing
# 2242 doc processing
# 2243 doc processing
# 2244 doc processing
# 2245 doc processing
# 2246 doc processing
# 2247 doc processing
# 2248 doc processing
# 2249 doc processing
# 2250 doc processing
# 2251 doc processing
# 2252 doc processing
# 2253 doc processing
# 2254 doc processing
# 2255 doc processing
# 2256 doc processing
# 2257 doc processing
# 2258 doc processing
# 2259 doc processing
# 2260 doc processing
# 2261 doc processing
# 2262 doc processing
# 2263 doc processing
# 2264 doc processing
# 2265 doc processing
# 2266 doc processing
# 2267 doc processing
# 2268 doc processing
# 2269 doc processing
# 2270 doc processing
# 2271 doc processing
# 2272 doc processing
# 2273 doc processing
# 2274 doc processing
# 2275 doc processing
# 2276 doc processing
# 2277 doc processing
# 2278 doc processing
# 2279 doc processing
# 2280 doc processing
# 2281 doc processing
# 2282 doc processing
# 2283 doc processing
# 2284 doc processing
# 2285 doc processing
# 2286 doc processing
# 2287 doc processing
# 2288 doc processing
# 2289 doc processing
# 2290 doc processing
# 2291 doc processing
# 2292 doc processing
# 2293 doc processing
# 2294 doc processing
# 2295 doc processing
# 2296 doc processing
# 2297 doc processing
# 2298 doc processing
# 2299 doc processing
# 2300 doc processing
# 2301 doc processing
# 2302 doc processing
# 2303 doc processing
# 2304 doc processing
# 2305 doc processing
# 2306 doc processing
# 2307 doc processing
# 2308 doc processing
# 2309 doc processing
# 2310 doc processing
# 2311 doc processing
# 2312 doc processing
# 2313 doc processing
# 2314 doc processing
# 2315 doc processing
# 2316 doc processing
# 2317 doc processing
# 2318 doc processing
# 2319 doc processing
# 2320 doc processing
# 2321 doc processing
# 2322 doc processing
# 2323 doc processing
# 2324 doc processing
# 2325 doc processing
# 2326 doc processing
# 2327 doc processing
# 2328 doc processing
# 2329 doc processing
# 2330 doc processing
# 2331 doc processing
# 2332 doc processing
# 2333 doc processing
# 2334 doc processing
# 2335 doc processing
# 2336 doc processing
# 2337 doc processing
# 2338 doc processing
# 2339 doc processing
# 2340 doc processing
# 2341 doc processing
# 2342 doc processing
# 2343 doc processing
# 2344 doc processing
# 2345 doc processing
# 2346 doc processing
# 2347 doc processing
# 2348 doc processing
# 2349 doc processing
# 2350 doc processing
# 2351 doc processing
# 2352 doc processing
# 2353 doc processing
# 2354 doc processing
# 2355 doc processing
# 2356 doc processing
# 2357 doc processing
# 2358 doc processing
# 2359 doc processing
# 2360 doc processing
# 2361 doc processing
# 2362 doc processing
# 2363 doc processing
# 2364 doc processing
# 2365 doc processing
# 2366 doc processing
# 2367 doc processing
# 2368 doc processing
# 2369 doc processing
# 2370 doc processing
# 2371 doc processing
# 2372 doc processing
# 2373 doc processing
# 2374 doc processing
# 2375 doc processing
# 2376 doc processing
# 2377 doc processing
# 2378 doc processing
# 2379 doc processing
# 2380 doc processing
# 2381 doc processing
# 2382 doc processing
# 2383 doc processing
# 2384 doc processing
# 2385 doc processing
# 2386 doc processing
# 2387 doc processing
# 2388 doc processing
# 2389 doc processing
# 2390 doc processing
# 2391 doc processing
# 2392 doc processing
# 2393 doc processing
# 2394 doc processing
# 2395 doc processing
# 2396 doc processing
# 2397 doc processing
# 2398 doc processing
# 2399 doc processing
# 2400 doc processing
# 2401 doc processing
# 2402 doc processing
# 2403 doc processing
# 2404 doc processing
# 2405 doc processing
# 2406 doc processing
# 2407 doc processing
# 2408 doc processing
# 2409 doc processing
# 2410 doc processing
# 2411 doc processing
# 2412 doc processing
# 2413 doc processing
# 2414 doc processing
# 2415 doc processing
# 2416 doc processing
# 2417 doc processing
# 2418 doc processing
# 2419 doc processing
# 2420 doc processing
# 2421 doc processing
# 2422 doc processing
# 2423 doc processing
# 2424 doc processing
# 2425 doc processing
# 2426 doc processing
# 2427 doc processing
# 2428 doc processing
# 2429 doc processing
# 2430 doc processing
# 2431 doc processing
# 2432 doc processing
# 2433 doc processing
# 2434 doc processing
# 2435 doc processing
# 2436 doc processing
# 2437 doc processing
# 2438 doc processing
# 2439 doc processing
# 2440 doc processing
# 2441 doc processing
# 2442 doc processing
# 2443 doc processing
# 2444 doc processing
# 2445 doc processing
# 2446 doc processing
# 2447 doc processing
# 2448 doc processing
# 2449 doc processing
# 2450 doc processing
# 2451 doc processing
# 2452 doc processing
# 2453 doc processing
# 2454 doc processing
# 2455 doc processing
# 2456 doc processing
# 2457 doc processing
# 2458 doc processing
# 2459 doc processing
# 2460 doc processing
# 2461 doc processing
# 2462 doc processing
# 2463 doc processing
# 2464 doc processing
# 2465 doc processing
# 2466 doc processing
# 2467 doc processing
# 2468 doc processing
# 2469 doc processing
# 2470 doc processing
# 2471 doc processing
# 2472 doc processing
# 2473 doc processing
# 2474 doc processing
# 2475 doc processing
# 2476 doc processing
# 2477 doc processing
# 2478 doc processing
# 2479 doc processing
# 2480 doc processing
# 2481 doc processing
# 2482 doc processing
# 2483 doc processing
# 2484 doc processing
# 2485 doc processing
# 2486 doc processing
# 2487 doc processing
# 2488 doc processing
# 2489 doc processing
# 2490 doc processing
# 2491 doc processing
# 2492 doc processing
# 2493 doc processing
# 2494 doc processing
# 2495 doc processing
# 2496 doc processing
# 2497 doc processing
# 2498 doc processing
# 2499 doc processing
# 2500 doc processing
# 2501 doc processing
# 2502 doc processing
# 2503 doc processing
# 2504 doc processing
# 2505 doc processing
# 2506 doc processing
# 2507 doc processing
# 2508 doc processing
# 2509 doc processing
# 2510 doc processing
# 2511 doc processing
# 2512 doc processing
# 2513 doc processing
# 2514 doc processing
# 2515 doc processing
# 2516 doc processing
# 2517 doc processing
# 2518 doc processing
# 2519 doc processing
# 2520 doc processing
# 2521 doc processing
# 2522 doc processing
# 2523 doc processing
# 2524 doc processing
# 2525 doc processing
# 2526 doc processing
# 2527 doc processing
# 2528 doc processing
# 2529 doc processing
# 2530 doc processing
# 2531 doc processing
# 2532 doc processing
# 2533 doc processing
# 2534 doc processing
# 2535 doc processing
# 2536 doc processing
# 2537 doc processing
# 2538 doc processing
# 2539 doc processing
# 2540 doc processing
# 2541 doc processing
# 2542 doc processing
# 2543 doc processing
# 2544 doc processing
# 2545 doc processing
# 2546 doc processing
# 2547 doc processing
# 2548 doc processing
# 2549 doc processing
# 2550 doc processing
# 2551 doc processing
# 2552 doc processing
# 2553 doc processing
# 2554 doc processing
# 2555 doc processing
# 2556 doc processing
# 2557 doc processing
# 2558 doc processing
# 2559 doc processing
# 2560 doc processing
# 2561 doc processing
# 2562 doc processing
# 2563 doc processing
# 2564 doc processing
# 2565 doc processing
# 2566 doc processing
# 2567 doc processing
# 2568 doc processing
# 2569 doc processing
# 2570 doc processing
# 2571 doc processing
# 2572 doc processing
# 2573 doc processing
# 2574 doc processing
# 2575 doc processing
# 2576 doc processing
# 2577 doc processing
# 2578 doc processing
# 2579 doc processing
# 2580 doc processing
# 2581 doc processing
# 2582 doc processing
# 2583 doc processing
# 2584 doc processing
# 2585 doc processing
# 2586 doc processing
# 2587 doc processing
# 2588 doc processing
# 2589 doc processing
# 2590 doc processing
# 2591 doc processing
# 2592 doc processing
# 2593 doc processing
# 2594 doc processing
# 2595 doc processing
# 2596 doc processing
# 2597 doc processing
# 2598 doc processing
# 2599 doc processing
# 2600 doc processing
# 2601 doc processing
# 2602 doc processing
# 2603 doc processing
# 2604 doc processing
# 2605 doc processing
# 2606 doc processing
# 2607 doc processing
# 2608 doc processing
# 2609 doc processing
# 2610 doc processing
# 2611 doc processing
# 2612 doc processing
# 2613 doc processing
# 2614 doc processing
# 2615 doc processing
# 2616 doc processing
# 2617 doc processing
# 2618 doc processing
# 2619 doc processing
# 2620 doc processing
# 2621 doc processing
# 2622 doc processing
# 2623 doc processing
# 2624 doc processing
# 2625 doc processing
# 2626 doc processing
# 2627 doc processing
# 2628 doc processing
# 2629 doc processing
# 2630 doc processing
# 2631 doc processing
# 2632 doc processing
# 2633 doc processing
# 2634 doc processing
# 2635 doc processing
# 2636 doc processing
# 2637 doc processing
# 2638 doc processing
# 2639 doc processing
# 2640 doc processing
# 2641 doc processing
# 2642 doc processing
# 2643 doc processing
# 2644 doc processing
# 2645 doc processing
# 2646 doc processing
# 2647 doc processing
# 2648 doc processing
# 2649 doc processing
# 2650 doc processing
# 2651 doc processing
# 2652 doc processing
# 2653 doc processing
# 2654 doc processing
# 2655 doc processing
# 2656 doc processing
# 2657 doc processing
# 2658 doc processing
# 2659 doc processing
# 2660 doc processing
# 2661 doc processing
# 2662 doc processing
# 2663 doc processing
# 2664 doc processing
# 2665 doc processing
# 2666 doc processing
# 2667 doc processing
# 2668 doc processing
# 2669 doc processing
# 2670 doc processing
# 2671 doc processing
# 2672 doc processing
# 2673 doc processing
# 2674 doc processing
# 2675 doc processing
# 2676 doc processing
# 2677 doc processing
# 2678 doc processing
# 2679 doc processing
# 2680 doc processing
# 2681 doc processing
# 2682 doc processing
# 2683 doc processing
# 2684 doc processing
# 2685 doc processing
# 2686 doc processing
# 2687 doc processing
# 2688 doc processing
# 2689 doc processing
# 2690 doc processing
# 2691 doc processing
# 2692 doc processing
# 2693 doc processing
# 2694 doc processing
# 2695 doc processing
# 2696 doc processing
# 2697 doc processing
# 2698 doc processing
# 2699 doc processing
# 2700 doc processing
# 2701 doc processing
# 2702 doc processing
# 2703 doc processing
# 2704 doc processing
# 2705 doc processing
# 2706 doc processing
# 2707 doc processing
# 2708 doc processing
# 2709 doc processing
# 2710 doc processing
# 2711 doc processing
# 2712 doc processing
# 2713 doc processing
# 2714 doc processing
# 2715 doc processing
# 2716 doc processing
# 2717 doc processing
# 2718 doc processing
# 2719 doc processing
# 2720 doc processing
# 2721 doc processing
# 2722 doc processing
# 2723 doc processing
# 2724 doc processing
# 2725 doc processing
# 2726 doc processing
# 2727 doc processing
# 2728 doc processing
# 2729 doc processing
# 2730 doc processing
# 2731 doc processing
# 2732 doc processing
# 2733 doc processing
# 2734 doc processing
# 2735 doc processing
# 2736 doc processing
# 2737 doc processing
# 2738 doc processing
# 2739 doc processing
# 2740 doc processing
# 2741 doc processing
# 2742 doc processing
# 2743 doc processing
# 2744 doc processing
# 2745 doc processing
# 2746 doc processing
# 2747 doc processing
# 2748 doc processing
# 2749 doc processing
# 2750 doc processing
# 2751 doc processing
# 2752 doc processing
# 2753 doc processing
# 2754 doc processing
# 2755 doc processing
# 2756 doc processing
# 2757 doc processing
# 2758 doc processing
# 2759 doc processing
# 2760 doc processing
# 2761 doc processing
# 2762 doc processing
# 2763 doc processing
# 2764 doc processing
# 2765 doc processing
# 2766 doc processing
# 2767 doc processing
# 2768 doc processing
# 2769 doc processing
# 2770 doc processing
# 2771 doc processing
# 2772 doc processing
# 2773 doc processing
# 2774 doc processing
# 2775 doc processing
# 2776 doc processing
# 2777 doc processing
# 2778 doc processing
# 2779 doc processing
# 2780 doc processing
# 2781 doc processing
# 2782 doc processing
# 2783 doc processing
# 2784 doc processing
# 2785 doc processing
# 2786 doc processing
# 2787 doc processing
# 2788 doc processing
# 2789 doc processing
# 2790 doc processing
# 2791 doc processing
# 2792 doc processing
# 2793 doc processing
# 2794 doc processing
# 2795 doc processing
# 2796 doc processing
# 2797 doc processing
# 2798 doc processing
# 2799 doc processing
# 2800 doc processing
# 2801 doc processing
# 2802 doc processing
# 2803 doc processing
# 2804 doc processing
# 2805 doc processing
# 2806 doc processing
# 2807 doc processing
# 2808 doc processing
# 2809 doc processing
# 2810 doc processing
# 2811 doc processing
# 2812 doc processing
# 2813 doc processing
# 2814 doc processing
# 2815 doc processing
# 2816 doc processing
# 2817 doc processing
# 2818 doc processing
# 2819 doc processing
# 2820 doc processing
# 2821 doc processing
# 2822 doc processing
# 2823 doc processing
# 2824 doc processing
# 2825 doc processing
# 2826 doc processing
# 2827 doc processing
# 2828 doc processing
# 2829 doc processing
# 2830 doc processing
# 2831 doc processing
# 2832 doc processing
# 2833 doc processing
# 2834 doc processing
# 2835 doc processing
# 2836 doc processing
# 2837 doc processing
# 2838 doc processing
# 2839 doc processing
# 2840 doc processing
# 2841 doc processing
# 2842 doc processing
# 2843 doc processing
# 2844 doc processing
# 2845 doc processing
# 2846 doc processing
# 2847 doc processing
# 2848 doc processing
# 2849 doc processing
# 2850 doc processing
# 2851 doc processing
# 2852 doc processing
# 2853 doc processing
# 2854 doc processing
# 2855 doc processing
# 2856 doc processing
# 2857 doc processing
# 2858 doc processing
# 2859 doc processing
# 2860 doc processing
# 2861 doc processing
# 2862 doc processing
# 2863 doc processing
# 2864 doc processing
# 2865 doc processing
# 2866 doc processing
# 2867 doc processing
# 2868 doc processing
# 2869 doc processing
# 2870 doc processing
# 2871 doc processing
# 2872 doc processing
# 2873 doc processing
# 2874 doc processing
# 2875 doc processing
# 2876 doc processing
# 2877 doc processing
# 2878 doc processing
# 2879 doc processing
# 2880 doc processing
# 2881 doc processing
# 2882 doc processing
# 2883 doc processing
# 2884 doc processing
# 2885 doc processing
# 2886 doc processing
# 2887 doc processing
# 2888 doc processing
# 2889 doc processing
# 2890 doc processing
# 2891 doc processing
# 2892 doc processing
# 2893 doc processing
# 2894 doc processing
# 2895 doc processing
# 2896 doc processing
# 2897 doc processing
# 2898 doc processing
# 2899 doc processing
# 2900 doc processing
# 2901 doc processing
# 2902 doc processing
# 2903 doc processing
# 2904 doc processing
# 2905 doc processing
# 2906 doc processing
# 2907 doc processing
# 2908 doc processing
# 2909 doc processing
# 2910 doc processing
# 2911 doc processing
# 2912 doc processing
# 2913 doc processing
# 2914 doc processing
#       FileName  ...                                        cleaned_doc
# 0            1  ...  masud khan v state uttar pradesh supreme court...
# 1            2  ...  indian oil corporation v nepc india limited ot...
# 2            3  ...  gurpal singh v state punjab others supreme cou...
# 3            4  ...  budh singh others v state uttar pradesh suprem...
# 4            5  ...  anil kumar v state supreme court india 13 febr...
# ...        ...  ...                                                ...
# 2909      2910  ...  sukhram v state maharashtra supreme court indi...
# 2910      2911  ...  satvir v state uttar pradesh supreme court ind...
# 2911      2912  ...  dharangadhara chemical work limited v state sa...
# 2912      2913  ...  central bank india v sethumadhavan others supr...
# 2913      2914  ...  som raj soma v state hp supreme court india 22...
#
# [2914 rows x 3 columns]

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

#K Means Clustering! 

true_k = 55 #setting it to sqroot(3000) for optimal k
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

for i in range(true_k):
  print("Cluster %d:" % i),
  for ind in order_centroids[i, :10]:
    print("%s" % terms[ind])
  
  print()

#We can use these clusters and predict which cluster each query belongs to!
# Out:
# Cluster 0:
# girl
# parade
# gangu
# child
# respondent
# identification
# house
# shop
# body
# court
#
# Cluster 1:
# detention
# detenu
# detaining
# advisory
# representation
# delay
# order
# authority
# board
# government
#
# Cluster 2:
# pw
# witness
# evidence
# court
# prosecution
# appellant
# singh
# accused
# pw2
# bhagelu
#
# Cluster 3:
# court
# appointment
# respondent
# regularization
# employee
# service
# labour
# writ
# employment
# appointed
#
# Cluster 4:
# award
# arbitrator
# arbitration
# circular
# court
# jetting
# respondent
# proceeding
# claim
# contractor
#
# Cluster 5:
# dying
# declaration
# deceased
# doctor
# statement
# recorded
# court
# magistrate
# renuka
# janak
#
# Cluster 6:
# court
# high
# petition
# writ
# art
# case
# public
# power
# order
# remark
#
# Cluster 7:
# injury
# death
# deceased
# blow
# cause
# bodily
# intention
# appellant
# 300
# inflict
#
# Cluster 8:
# ornament
# court
# acquittal
# retrial
# admissible
# hidden
# case
# distinctly
# high
# evidence
#
# Cluster 9:
# identification
# parade
# appellant
# witness
# court
# identified
# accused
# evidence
# test
# singh
#
# Cluster 10:
# wage
# service
# reinstatement
# respondent
# petitioner
# court
# 1409
# 1996
# order
# case
#
# Cluster 11:
# court
# ramalingam
# deceased
# pw1
# accused
# bimlabai
# high
# evidence
# pw3
# exhibit
#
# Cluster 12:
# sentence
# section
# court
# accused
# offence
# liquor
# death
# prosecutrix
# ipc
# year
#
# Cluster 13:
# court
# accused
# act
# firearm
# respondent
# case
# trial
# scooter
# charge
# offence
#
# Cluster 14:
# notification
# land
# writ
# petition
# sadhurakhurd
# section
# acquisition
# ramjas
# mubarikabad
# act
#
# Cluster 15:
# land
# acquired
# solatium
# acquisition
# court
# building
# value
# market
# award
# compensation
#
# Cluster 16:
# service
# employment
# contract
# servant
# temporary
# government
# rule
# removal
# dismissal
# post
#
# Cluster 17:
# scientist
# exservicemen
# allowance
# medical
# ministry
# service
# facility
# personnel
# health
# nonmedical
#
# Cluster 18:
# age
# 58
# service
# year
# 60
# caseii
# committee
# superannuation
# respondent
# casei
#
# Cluster 19:
# mother
# appellant
# moradabad
# hotel
# jewellery
# money
# mahendra
# grand
# evidence
# infant
#
# Cluster 20:
# jungle
# clearance
# work
# nomination
# engineer
# contractor
# nellore
# pw
# 197980
# site
#
# Cluster 21:
# cm
# court
# shankara
# pellet
# acquittal
# accused
# trial
# injury
# scissors
# evidence
#
# Cluster 22:
# jury
# rangnath
# girl
# shilavati
# appellant
# kashinath
# sandhya
# charge
# verdict
# summarily
#
# Cluster 23:
# forest
# tree
# felling
# state
# certificate
# act
# instalment
# sale
# contract
# government
#
# Cluster 24:
# court
# appeal
# accused
# high
# acquittal
# trial
# evidence
# appellate
# appellant
# case
#
# Cluster 25:
# candidate
# rule
# age
# selection
# relaxation
# mark
# commission
# vacancy
# advertisement
# recruitment
#
# Cluster 26:
# accused
# deceased
# pw
# evidence
# court
# appellant
# manju
# house
# a1
# prosecution
#
# Cluster 27:
# container
# builder
# plaintiff
# allotment
# court
# estate
# resumption
# defendant
# committee
# scheme
#
# Cluster 28:
# petitioner
# bail
# court
# case
# jail
# foreigner
# shrc
# rule
# seat
# pakistan
#
# Cluster 29:
# yadao
# a4ram
# somani
# a1gopal
# maharaj
# pw2anil
# chaudhary
# a4
# ramu
# prasad
#
# Cluster 30:
# corporation
# employee
# company
# government
# contract
# act
# regulation
# art
# india
# ore
#
# Cluster 31:
# pw
# ornament
# gold
# sukhbasi
# silk
# sanehi
# house
# saree
# deceased
# stolen
#
# Cluster 32:
# court
# complaint
# sanction
# servant
# offence
# respondent
# public
# criminal
# proceeding
# civil
#
# Cluster 33:
# cheque
# appellant
# bank
# court
# presumption
# evidence
# subordinate
# accused
# shri
# employer
#
# Cluster 34:
# compulsory
# retirement
# court
# service
# jain
# retire
# remark
# government
# high
# adverse
#
# Cluster 35:
# junior
# engineer
# byelaw
# cadre
# scientific
# tribunal
# technical
# promotion
# graduate
# retrospective
#
# Cluster 36:
# partner
# partnership
# firm
# arbitrator
# award
# property
# asset
# share
# depreciation
# value
#
# Cluster 37:
# treadrubber
# production
# collector
# anam
# meter
# factory
# consumption
# figure
# 173e
# estimated
#
# Cluster 38:
# public
# court
# litigation
# market
# petition
# writ
# petitioner
# sc
# personal
# tea
#
# Cluster 39:
# kaur
# rita
# gian
# balvinder
# motherinlaw
# court
# burn
# parent
# high
# dying
#
# Cluster 40:
# cbi
# court
# investigation
# power
# consent
# state
# government
# agency
# constitution
# police
#
# Cluster 41:
# solicitor
# respondent
# tender
# contract
# 10001
# appellant
# conveyance
# agreement
# 1943
# suit
#
# Cluster 42:
# tenant
# tenancy
# landlord
# building
# rent
# land
# act
# 54
# provision
# trust
#
# Cluster 43:
# tribeni
# sahai
# balak
# banney
# ram
# kohli
# jhilmili
# radhey
# khan
# dharam
#
# Cluster 44:
# aiims
# medical
# reimbursement
# policy
# hospital
# escort
# treatment
# surgery
# punjab
# new
#
# Cluster 45:
# conspiracy
# offence
# agreement
# committed
# act
# dubai
# conspirator
# india
# 188
# illegal
#
# Cluster 46:
# surety
# advocate
# notice
# thankappan
# court
# srinivasan
# affidavit
# appellant
# attested
# nair
#
# Cluster 47:
# shankar
# subash
# shiv
# babu
# dinesh
# identification
# parade
# kha
# ram
# witness
#
# Cluster 48:
# nylon
# resin
# yarn
# plastic
# twine
# synthetic
# assessee
# item
# polymer
# fibre
#
# Cluster 49:
# sal
# seed
# mt
# agreement
# unit
# royalty
# renewal
# oil
# singhvi
# mp
#
# Cluster 50:
# representation
# detention
# government
# delay
# detenu
# file
# central
# 1993
# minister
# secretary
#
# Cluster 51:
# child
# sunil
# nikita
# sharda
# tara
# court
# nicker
# a1
# police
# pw8
#
# Cluster 52:
# enquiry
# rajpal
# meena
# radhey
# statement
# mishra
# shiv
# shyam
# officer
# laborer
#
# Cluster 53:
# vithal
# bhimrao
# wada
# accused
# common
# 19
# section
# object
# 18
# inside
#
# Cluster 54:
# singh
# tara
# accused
# witness
# evidence
# court
# deceased
# surender
# reexamination
# person

# %%
#Import query.csv and use TF-IDF and get k relevant docs using cosine similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

tfIdfVectorizer=TfidfVectorizer(max_features=10000,use_idf=True,stop_words='english',min_df = 0.01,max_df=0.7)
tfIdf = tfIdfVectorizer.fit_transform(documents)

tfidf_df = pd.DataFrame(tfIdf[0].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF-IDF"])
tfidf_df = tfidf_df.sort_values('TF-IDF', ascending=False)
print (tfidf_df)
# Out:
#                 TF-IDF
# estoppel      0.390167
# petitioner    0.336668
# issue         0.229910
# proceeding    0.218524
# crown         0.213927
# ...                ...
# disagreed     0.000000
# disagree      0.000000
# disadvantage  0.000000
# disabled      0.000000
# zone          0.000000
#
# [6714 rows x 1 columns]

# %%
#Upload Query.csv 
#Clean Query
#Use TFIDF, Cosine similarity to get k=3 relevant docs!

#Make sure you've run the previous code blocks before executing this!

def remove_punctuation(text):
    #also whitespace
    translator = str.maketrans('', '', string.punctuation) 
    return text.translate(translator)

def remove_stop_words_and_lemmatize(sentence):
  sentence=remove_punctuation(sentence)
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(sentence) 
  word_tokens=[word.lower() for word in word_tokens]
  filtered_sentence = [w for w in word_tokens if not w in stop_words]
  cleaned=[token for token in filtered_sentence if not token.isdigit()] #remove numbers
  lemmatizer = WordNetLemmatizer()
  lemmatized_sentence=[lemmatizer.lemmatize(w) for w in filtered_sentence]  
  return lemmatized_sentence

N=2914 #3000
relevant_k=25
Q=50
from sklearn.metrics.pairwise import cosine_similarity
uploaded2 =files.upload()
qdf= pd.read_csv(io.BytesIO(uploaded2['query.csv']))
queries=list(qdf['Query'])
cleaned_queries=[]
relevant_docs=[] #top 3 relevant docs per query! 
idx=0
for line in queries:
    idx+=1
    #clean query
    tokens=remove_stop_words_and_lemmatize(line)
    query_string=' '.join(tokens)
    #query_string=" ".join([x for x in query_string.split() if x.isdigit() == False])
    query_string=' '.join(expand_query(query_string)) #expanding query by adding synonyms
    cleaned_queries.append(query_string)
    query_vec = tfIdfVectorizer.transform([query_string])
    results = cosine_similarity(tfIdf,query_vec)
    cosine_similarities=[]
    for doc_index in range(N):
      cosine_similarities.append((results[doc_index][0],doc_index+1))
    top_k=sorted(cosine_similarities,key=lambda x:x[0],reverse=True)[:relevant_k] #top k docs sorted by cosine similarity
    top_k_docs=[doc_idx for cs,doc_idx in top_k] #store only the doc indices
    relevant_docs.append(top_k_docs)
  


print("Printing queries and top 10 relevant docs by TF-IDF and cosine similarity\n")
qdf["query_string"]=cleaned_queries
qdf["top_k_docs"]=relevant_docs
print(qdf)
# Out:
#      <input type="file" id="files-b33af1db-0789-4d59-9a0f-6f390820e4ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b33af1db-0789-4d59-9a0f-6f390820e4ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving query.csv to query (10).csv
# Printing queries and top 10 relevant docs by TF-IDF and cosine similarity
#
#        Index  ...                                         top_k_docs
# 0    AILA_Q1  ...  [1240, 2907, 560, 723, 1051, 1012, 1776, 1542,...
# 1    AILA_Q2  ...  [2316, 1853, 2765, 2846, 2311, 2313, 1623, 22,...
# 2    AILA_Q3  ...  [246, 256, 1147, 294, 277, 1933, 103, 2322, 41...
# 3    AILA_Q4  ...  [1847, 859, 814, 2726, 151, 363, 2582, 2439, 1...
# 4    AILA_Q5  ...  [42, 1420, 2109, 707, 2827, 2830, 1874, 378, 2...
# 5    AILA_Q6  ...  [2771, 2201, 1529, 1805, 1874, 2109, 822, 880,...
# 6    AILA_Q7  ...  [705, 1968, 1630, 2392, 797, 2890, 1352, 676, ...
# 7    AILA_Q8  ...  [1766, 744, 169, 632, 2103, 751, 1431, 474, 97...
# 8    AILA_Q9  ...  [2040, 757, 532, 2799, 2109, 987, 979, 215, 13...
# 9   AILA_Q10  ...  [2260, 479, 1778, 2265, 1358, 2409, 2879, 522,...
# 10  AILA_Q11  ...  [1354, 2246, 730, 2730, 2158, 360, 175, 810, 3...
# 11  AILA_Q12  ...  [2246, 1108, 2158, 499, 1658, 299, 2472, 1632,...
# 12  AILA_Q13  ...  [1178, 40, 2412, 120, 2640, 1732, 362, 2541, 2...
# 13  AILA_Q14  ...  [1236, 46, 1874, 1993, 1496, 2089, 1543, 538, ...
# 14  AILA_Q15  ...  [297, 2810, 1302, 2687, 1739, 169, 1024, 979, ...
# 15  AILA_Q16  ...  [751, 1175, 459, 403, 744, 117, 2128, 2404, 27...
# 16  AILA_Q17  ...  [2246, 91, 2897, 2158, 730, 374, 1354, 1547, 8...
# 17  AILA_Q18  ...  [188, 116, 179, 115, 2639, 2350, 581, 436, 44,...
# 18  AILA_Q19  ...  [1529, 342, 2720, 538, 265, 2810, 1364, 1037, ...
# 19  AILA_Q20  ...  [1295, 459, 2021, 397, 2338, 1943, 645, 760, 1...
# 20  AILA_Q21  ...  [113, 2083, 1650, 1664, 639, 681, 238, 1554, 2...
# 21  AILA_Q22  ...  [169, 210, 1904, 363, 2270, 605, 2019, 2373, 2...
# 22  AILA_Q23  ...  [191, 1412, 2876, 913, 1473, 2468, 267, 2582, ...
# 23  AILA_Q24  ...  [1620, 2827, 947, 1277, 491, 1000, 64, 2717, 1...
# 24  AILA_Q25  ...  [2363, 2869, 1224, 2436, 755, 1022, 947, 41, 7...
# 25  AILA_Q26  ...  [581, 436, 116, 183, 2639, 1424, 179, 44, 504,...
# 26  AILA_Q27  ...  [732, 91, 2897, 1655, 375, 2246, 730, 2730, 14...
# 27  AILA_Q28  ...  [1593, 2733, 180, 1620, 1738, 223, 495, 109, 1...
# 28  AILA_Q29  ...  [751, 169, 459, 1855, 1329, 790, 2019, 163, 20...
# 29  AILA_Q30  ...  [459, 453, 1329, 833, 2019, 403, 655, 2169, 69...
# 30  AILA_Q31  ...  [377, 2504, 2034, 2551, 64, 723, 1277, 2043, 1...
# 31  AILA_Q32  ...  [744, 1769, 924, 1233, 979, 966, 1703, 1302, 2...
# 32  AILA_Q33  ...  [186, 2, 236, 2290, 1009, 1663, 1887, 32, 1738...
# 33  AILA_Q34  ...  [865, 1668, 2490, 158, 1847, 105, 191, 143, 16...
# 34  AILA_Q35  ...  [1376, 751, 2447, 2403, 1570, 2184, 42, 717, 1...
# 35  AILA_Q36  ...  [37, 57, 112, 55, 2683, 1868, 2429, 1226, 457,...
# 36  AILA_Q37  ...  [1135, 1148, 2163, 1379, 1376, 370, 1766, 1496...
# 37  AILA_Q38  ...  [1582, 186, 1741, 723, 919, 311, 1147, 103, 25...
# 38  AILA_Q39  ...  [1021, 562, 2738, 661, 538, 746, 695, 645, 239...
# 39  AILA_Q40  ...  [981, 731, 2456, 386, 1280, 1115, 1067, 689, 7...
# 40  AILA_Q41  ...  [1135, 2222, 2764, 1376, 1543, 1148, 1553, 233...
# 41  AILA_Q42  ...  [1199, 677, 24, 2, 1032, 425, 2794, 377, 2546,...
# 42  AILA_Q43  ...  [1847, 191, 712, 2497, 1473, 1560, 1668, 151, ...
# 43  AILA_Q44  ...  [2278, 1593, 1026, 723, 2733, 542, 1887, 2565,...
# 44  AILA_Q45  ...  [1364, 2338, 397, 2715, 459, 1855, 2019, 1957,...
# 45  AILA_Q46  ...  [2602, 1021, 1595, 979, 746, 2465, 1102, 163, ...
# 46  AILA_Q47  ...  [2340, 1053, 342, 1427, 1578, 1037, 1620, 2810...
# 47  AILA_Q48  ...  [162, 82, 1843, 21, 2254, 2815, 141, 1667, 113...
# 48  AILA_Q49  ...  [2721, 757, 2311, 2853, 1812, 981, 1623, 868, ...
# 49  AILA_Q50  ...  [2316, 1853, 22, 2846, 2765, 1812, 2311, 1623,...
#
# [50 rows x 4 columns]

# %%
#Uploading rel docs for comparison and evalutating!
import json
from google.colab import files
uploaded3 = files.upload()
rel_df= pd.read_csv(io.BytesIO(uploaded3['rel_docs.csv']))
print("\nTFIDF result—\n")
ans=[]
Q=50
for i,row in qdf.iterrows():
  tfidf_list=row['top_k_docs']
  given=json.loads(rel_df.iloc[i]['relevant'])
  matches=0 
  for ele in tfidf_list:
    if(ele in given):
      matches+=1
  precision_at_k=round(matches/relevant_k,2)
  recall_at_k=round(matches/len(given),2)
  ans.append({"index":"AILA_Q"+str(i+1),"top_k":tfidf_list,"relevant":given,"precision@k":precision_at_k,"recall@k":recall_at_k})



ans_df=pd.DataFrame(ans)
print(ans_df)
ans_df.to_csv('tfidf_eval.csv') 
files.download('tfidf_eval.csv')
ap=ans_df["precision@k"].sum()/Q
ar=ans_df["recall@k"].sum()/Q
print("The Avg. precision@k for all queries— ",ap)
print("The Avg. recall@k for all queries— ",ar)
f_score=(2*ap*ar)/ (ap+ar)
print("The F-score is ",f_score)
# Out:
#      <input type="file" id="files-302e13f7-e106-4517-8a7d-7fe6a963f073" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-302e13f7-e106-4517-8a7d-7fe6a963f073">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rel_docs.csv to rel_docs (8).csv
#
# TFIDF result—
#
#        index  ... recall@k
# 0    AILA_Q1  ...     0.00
# 1    AILA_Q2  ...     0.50
# 2    AILA_Q3  ...     0.00
# 3    AILA_Q4  ...     0.00
# 4    AILA_Q5  ...     0.00
# 5    AILA_Q6  ...     0.00
# 6    AILA_Q7  ...     0.00
# 7    AILA_Q8  ...     0.00
# 8    AILA_Q9  ...     0.00
# 9   AILA_Q10  ...     0.00
# 10  AILA_Q11  ...     0.50
# 11  AILA_Q12  ...     0.00
# 12  AILA_Q13  ...     0.67
# 13  AILA_Q14  ...     1.00
# 14  AILA_Q15  ...     0.00
# 15  AILA_Q16  ...     0.00
# 16  AILA_Q17  ...     0.00
# 17  AILA_Q18  ...     1.00
# 18  AILA_Q19  ...     0.00
# 19  AILA_Q20  ...     0.00
# 20  AILA_Q21  ...     0.50
# 21  AILA_Q22  ...     0.00
# 22  AILA_Q23  ...     0.00
# 23  AILA_Q24  ...     0.00
# 24  AILA_Q25  ...     0.33
# 25  AILA_Q26  ...     0.62
# 26  AILA_Q27  ...     0.20
# 27  AILA_Q28  ...     0.00
# 28  AILA_Q29  ...     0.14
# 29  AILA_Q30  ...     0.00
# 30  AILA_Q31  ...     0.00
# 31  AILA_Q32  ...     0.00
# 32  AILA_Q33  ...     1.00
# 33  AILA_Q34  ...     0.08
# 34  AILA_Q35  ...     0.00
# 35  AILA_Q36  ...     0.67
# 36  AILA_Q37  ...     0.00
# 37  AILA_Q38  ...     0.00
# 38  AILA_Q39  ...     0.25
# 39  AILA_Q40  ...     0.00
# 40  AILA_Q41  ...     0.00
# 41  AILA_Q42  ...     0.50
# 42  AILA_Q43  ...     0.33
# 43  AILA_Q44  ...     0.50
# 44  AILA_Q45  ...     0.00
# 45  AILA_Q46  ...     0.00
# 46  AILA_Q47  ...     0.00
# 47  AILA_Q48  ...     1.00
# 48  AILA_Q49  ...     0.00
# 49  AILA_Q50  ...     0.50
#
# [50 rows x 5 columns]
# The Avg. precision@k for all queries—  0.039
# The Avg. recall@k for all queries—  0.2058
# The F-score is  0.06557352941176471
